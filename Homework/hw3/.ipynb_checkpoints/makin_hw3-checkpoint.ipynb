# %% [markdown]
# # Алгоритмы интеллектуальной обработки больших объемов данных
# ## Домашнее задание №3: Линейные модели

# %% [markdown]
# **Общая информация**
#
# **Срок сдачи:** 17 ноября 2018, 06:00 <br\>
# **Штраф за опоздание:** -2 балла после 06:00 17 ноября, -4 балла после 06:00 24 ноября, -6 баллов после 06:00 1 декабря, -8 баллов после 06:00 8 декабря.
#
# При отправлении ДЗ указывайте фамилию в названии файла<br\>
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.
#
# **Штрафные баллы:**
#
# 1. Невыполнение PEP8 -1 балл
# 2. Отсутствие фамилии в имени скрипта (скрипт должен называться по аналогии со stroykova_hw2.ipynb) -1 балл
# 3. Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть уже в git'е. В противном случае -1 балл
# 4. При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. Не нужно удалять и видоизменять написанный код и текст, если явно не указана такая возможность. В противном случае -1 балл

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, ClassifierMixin

# %matplotlib inline
# %load_ext pycodestyle_magic
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %% [markdown]
# # Определям, что вам досталось

# %% [markdown]
# <center><img src='https://static1.squarespace.com/static/571a6e39b6aa608067028725/t/577988518419c2d62fb5922f/1467582555915/'></center>

# %% [markdown]
# Укажите свою фамилию на русском языке в поле ниже.

# %%
USER_NAME = u"Mакин".lower()
REGULARIZATIONS = ["L1", "L2"]
ALGORITHM = ["", "Mini Batch"]

print ("Имплементируйте обучение логистической регрессии с %s регуляризацией с помощью метода %s Stochastic Gradient Descent (SGD)"\
% (
    REGULARIZATIONS[hash(USER_NAME) % 2],
    ALGORITHM[hash(USER_NAME[::-1]) % 2]
) )
# Out:
# Имплементируйте обучение логистической регрессии с L2 регуляризацией с помощью метода Mini Batch Stochastic Gradient Descent (SGD)

# %% [markdown]
# # Теоретическое введение

# %% [markdown]
# *** Что почитать по теории ***
#
# Одна из лучших книг по ML $-$ "Pattern Recognition and Machine Learning" Bishop, Christopher. Логистическая регрессия в ней в параграфе 4.3

# %% [markdown]
# Логистическая регрессия является линейным классификатором, который оптимизирует так называемый функционал log loss:

# %% [markdown]
# $$L(w) = - \frac{1}{N}\left[\sum_i y_i \log a_i + ( 1 - y_i) \log (1 - a_i) \right],$$
# где  $y_i  \in \{0,1\}$ $-$ метка класса, $a_i$ $-$ предсказание алгоритма на объекте $x_i$. Модель пытается предсказать апостериорую вероятность объекта принадлежать к классу "1":
# $$ p(y_i = 1 | x_i) = a(x_i) =  \sigma( \langle\,x_i,w\rangle ),$$
# где $w$ $-$ вектор весов (размерности $D$), $x_i$ $-$ вектор признаков (такой же размерности $D$).
#
# Функция $\sigma(x)$ $-$ нелинейная функция, пероводящее скалярное произведение объекта на веса в число $\in (0,1)$ (мы же моделируем вероятность все-таки!)
#
# $$\sigma(x) = \frac{1}{1 + \exp(-x)}$$
#
# Если внимательно посмотреть на функцию потерь, то можно заметить, что в зависимости от правильного ответа алгоритм штрафуется или функцией $-\log a_i$, или функцией $-\log (1 - a_i)$.

# %% [markdown]
# Часто для решения проблем, которые так или иначе связаны с проблемой переобучения, в функционал качества добавляют слагаемое, которое называют ***регуляризацией***. Итоговый функционал тогда принимает вид:
# $$L(w) = - \frac{1}{N}\left[\sum_i y_i \log a_i + ( 1 - y_i) \log (1 - a_i) \right] +  \frac{1}{C}R(w)$$
#
# Самое понятие регуляризации введено основателем ВМК академиком Тихоновым https://ru.wikipedia.org/wiki/Метод_регуляризации_Тихонова
#
# Идейно методика регуляризации заключается в следующем $-$ мы рассматриваем некорректно поставленную задачу (что это такое можно найти в интернете), для того чтобы сузить набор различных вариантов (лучшие из которых будут являться переобучением ) мы вводим дополнительные ограничения на множество искомых решений. На лекции Вы уже рассмотрели два варианта регуляризации.
#
# $L1$ регуляризация:
# $$R(w) = \sum_{j=1}^{D}|w_j|$$
# $L2$ регуляризация:
# $$R(w) =  \sum_{j=1}^{D}w_j^2$$
#
# С их помощью мы ограничиваем модель в  возможности выбора каких угодно весов минимизирующих наш лосс, модель уже не сможет подстроиться под данные как ей угодно.
#
# Вам нужно добавить соотвествущую Вашему варианту регуляризацию в функцию потерь.
#
# И так, мы поняли, какую функцию ошибки будем минимизировать, разобрались, как получить предсказания по объекту и обученным весам. Осталось разобраться, как получить оптимальные веса. Для этого нужно выбрать какой-то метод оптимизации. Отметим, что вне зависимости от алгоритма оптимизации, данная модель все равно будет называться ***логистической регрессией***.

# %% [markdown]
# Градиентный спуск является самым популярным алгоритмом обучения линейных моделей. В этом задании Вам предложат реализовать стохастический градиентный спуск или  мини-батч градиентный спуск (мини-батч на русский язык довольно сложно перевести, многие переводят это как "пакетный", но мне не кажется этот перевод удачным). Далее нам потребуется определение **эпохи**.
# Эпохой в SGD и MB-GD называется один проход по **всем** объектам в обучающей выборки.
# * В SGD градиент расчитывается по одному случайному объекту. Сам алгоритм выглядит примерно так:
#         1) Перемешать выборку
#         2) Посчитать градиент функции потерь на одном объекте (далее один объект тоже будем называть батчем)
#         3) Сделать шаг спуска
#         4) Повторять 2) и 3) пока не пройдет максимальное число эпох.
# * В Mini Batch SGD - по подвыборке объектов. Сам алгоритм выглядит примерно так::
#         1) Перемешать выборку
#         2) Почитать градиент функции потерь по мини-батчу (не забыть поделить на  число объектов в мини-батче)
#         3) Сделать шаг спуска
#         4) Повторять 2) и 3) пока не пройдет максимальное число эпох.
# * Для отладки алгоритма реализуйте возможность  вывода средней ошибки на обучении модели по объектам (мини-батчам). После шага градиентного спуска посчитайте значение ошибки на объекте (или мини-батче), а затем усредните, например, по ста шагам. Если обучение проходит корректно, то мы должны увидеть, что каждые 100 шагов функция потерь уменьшается.
# * Правило останова - максимальное количество эпох

# %% [markdown]
# ### Примечание для случая L1-регуляризации:
#
# При расчете производной по функции потерь c L1-регуляризацией  могут возникнуть сомнения по поводу производной части с модулями.
#
# Вам на выбор предлагаются следующией варианты:
# * Считать субградиент $\partial|w_j| = sign(w_j)$ (проще, но с большой вероятностью не приведет к занулению коэффициентов)
# * Метод SGD-Clipping из [статьи](https://www.aclweb.org/anthology/P/P09/P09-1054.pdf) - раздел 3.1, страница 479, правая колонка снизу (чуть сложнее, но зато должно занулять)
# * Cumulative Penalty из той же [статьи](https://www.aclweb.org/anthology/P/P09/P09-1054.pdf) - раздел 3.2

# %% [markdown]
# # Теоретические вопросы (2 балла)
# В этой части Вам будут предложены теоретичские вопросы и задачи по теме. Вы, конечно, можете списать их у своего товарища или найти решение в интернете, но учтите, что они обязательно войдут в теоретический коллоквиум. Лучше разобраться в теме сейчас и успешно ответить на коллоквиуме, чем списать, не разобравшись в материале, и быть терзаемым совестью.
#
#
# Формулы надо оформлять в формате **LaTeX**.

# %% [markdown]
# ### ***Задача 1. Градиент для логистической регрессии***
# * Посчитайте градиент функции потерь по весам для модели логистической регрессии с конкретно Вашей регуляризацией:
#
# $$ \nabla_w L = \dots $$
#
#  Отнеситесь к этому пункту максимально серьезно, этот градиент Вам нужно будет реализовать в задании.

# %% [markdown]
# ## ***Решение:***
# Функционал имеет вид:
# $$L(w) = - \frac{1}{N}\left[\sum_i y_i \log a_i + ( 1 - y_i) \log (1 - a_i) \right] +  \frac{1}{C}R(w)$$
# $$ a(x_i) =  \sigma( \langle\,x_i,w\rangle ),$$
# $$\sigma(x) = \frac{1}{1 + \exp(-x)}$$
#
#
# В моём случае $L2$ регуляризация: $R(w) =  \sum_{j=1}^{D}w_j^2$
# Имеем тогда:
# $$L(w) = - \frac{1}{N}\sum_i \left[ y_i \log a_i + ( 1 - y_i) \log (1 - a_i) \right] +  \frac{1}{C}\sum_{j=1}^{D}w_j^2$$
# Найдём $$\frac{\partial L(w)}{\partial w_k}$$
# $$ \frac{\partial L(w)}{\partial w_k} = - \frac{1}{N}\sum_i \left[ y_i \frac{\partial \log a_i}{\partial w_k}  + ( 1 - y_i)\frac{\partial \log (1 - a_i)}{\partial w_k} \right] + \frac{1}{C}\sum_{j=1}^{D} \frac{\partial w_j^2}{\partial w_k} $$
#
# $$ \frac{\partial \sigma( \langle\,x_i,w\rangle )}{\partial w_k} =  \frac{\partial}{\partial w_k}\left(\frac{1}{1 + \exp(-\langle\,x_i,w\rangle)}\right) = \frac{\exp(-\langle\,x_i,w\rangle)}{\left(1 + \exp(-\langle\,x_i,w\rangle)\right)^2}x_{i,k} = \frac{1}{1 + \exp(-\langle\,x_i,w\rangle)}\left(1 - \frac{1}{1 + \exp(-\langle\,x_i,w\rangle)}\right)x_{i,k} = \sigma( \langle\,x_i,w\rangle )(1-\sigma( \langle\,x_i,w\rangle )x_{i,k}$$
#
# $$ \frac{\partial \log a_i}{\partial w_k} = \frac{1}{\sigma( \langle\,x_i,w\rangle )} \frac{\partial \sigma( \langle\,x_i,w\rangle )}{\partial w_k} = (1 - \sigma( \langle\,x_i,w\rangle )) x_{i,k} $$
#
# $$ \frac{\partial \log (1- a_i)}{\partial w_k} =  -\frac{1}{1 - \sigma( \langle\,x_i,w\rangle )} \frac{\partial \sigma( \langle\,x_i,w\rangle )}{\partial w_k} = -\sigma( \langle x_i,w\rangle ) x_{i,k} $$
#
# $$ \frac{\partial L(w)}{\partial w_k} = - \frac{1}{N}\sum_i \left[ y_i (1 - \sigma( \langle x_i,w\rangle )) x_{i,k} - ( 1 - y_i) \sigma( \langle x_i,w\rangle ) x_{i,k} \right] + \frac{2 w_k}{C} $$
#
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{1}{N}\sum_i  \left[x_{i,k} \left(\sigma( \langle x_i,w\rangle)- y_i\right)\right] + \frac{2 w_k}{C} $$
# ## ***Ответ:***
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{1}{N}\sum_i  \left[x_{i,k} \left(\sigma( \langle x_i,w\rangle)- y_i\right)\right] + \frac{2 w_k}{C}  = \frac{1}{N}\sum_i  \left[x_{i,k} \left(a(x_i)- y_i\right)\right] + \frac{2 w_k}{C} $$

# %% [markdown]
# ### ***Задача 2. Анализ поведения градиента***
#
# Посчитав формулу градиента, подумайте, как будут меняться веса в зависимости  от "вида" ошибки:
# * Если правильный ответ был  класс "1", а значение $a(x_i)$ близко к нулю, после шага градиентного спуска веса в среднем увеличатся или уменьшатся?
#
# * Если правильный ответ был  класс "0", а значение $a(x_i)$ близко к  единице, после шага градиентного спуска веса в среднем увеличатся или уменьшатся?
#
# Вам такое поведение кажется логичным?

# %% [markdown]
# ## ***Решение:***
#
# $$ w_k := w_k - \alpha\frac{\partial L(w)}{\partial w_k},\  \alpha -  скорость\ спуска$$
#
# $$ \frac{\partial L(w)}{\partial w_k} = - \frac{1}{N}\sum_i  \left[x_{i,k} \left( y_i - \sigma( \langle\,x_i,w\rangle )\right)\right] + \frac{2 w_k}{C} $$
#
# a) Если $y_i = 1,\   \sigma(\langle x_i, w\rangle) \approx 0,$
#
# Тогда имеем, если не учитывать регуляризацию:
# $$\frac{\partial L(w)}{\partial w_k} \approx - x_{i,k}, $$
#
# Тогда получаем:
#
# $$ w_k := w_k + \alpha x_{i,k} ,\alpha -  скорость\ спуска$$
#
# Смотря на эту формулу видно, что вес не будет уменьшаться
# (при условии, что: $x_{i,k}>=0$)
#
#
# b) Если $y_i = 0,\   \sigma(\langle x_i, w\rangle) \approx 1,$
#
# Тогда имеем, если не учитывать регуляризацию:
# $$\frac{\partial L(w)}{\partial w_k} \approx  x_{i,k}, $$
#
# Тогда получаем:
#
# $$ w_k := w_k - \alpha x_{i,k} ,\alpha -  скорость\ спуска$$
#
# Смотря на эту формулу видно, что вес не будет увеличиваться
# (при условии, что: $x_{i,k}>=0$)

# %% [markdown]
# ### ***Задача 3. Сравнение с линейной регрессией***
#
# Как было рассказано на лекции, функция потерь линейной регрессии без регуляризации имеет вид:
# $$ L( w ) = \frac{1}{N}\left[\sum_i (a(x_i) - y_i)^2 \right] $$
# где $a(x_i)$ предсказания модели на $i$ объекте, $y_i$ $-$ значение целовой переменной на $i$ объекте, $N$ $-$ размер выборки.
# $a(x_i)$ через веса и признаки вычисляется как:
# $$ a(x_i) =  \langle\,x_i,w\rangle $$
# где $x_i$ $-$ вектор признаков, $w$ $-$ вектор весов модели.
# * Посчитайте градиент  функции потерь по весам для модели линейной регрессии:
# $$ \nabla_w L = \dots $$
# Как соотносится этот градиент с градиентом, возникающий в задаче логистической регресии? Вас это удивило, Вы это уже раньше заметили или Вам все равно?

# %% [markdown]
# ## ***Решение:***
# Функционал имеет вид:
# $$ L( w ) = \frac{1}{N}\left[\sum_i (a(x_i) - y_i)^2 \right] + \frac{1}{C}R(w)$$
# $$ a(x_i) =  \langle\,x_i,w\rangle$$
#
#
# В моём случае $L2$ регуляризация: $R(w) =  \sum_{j=1}^{D}w_j^2$
# Имеем тогда:
# $$L(w) = \frac{1}{N}\left[\sum_i (a(x_i) - y_i)^2 \right] + \frac{1}{C}\sum_{j=1}^{D}w_j^2$$
#
# Найдём $$\frac{\partial L(w)}{\partial w_k}$$
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{1}{N}\sum_i \frac{\partial}{\partial w_k}(a(x_i) - y_i)^2 + \frac{1}{C}\sum_{j=1}^{D} \frac{\partial w_j^2}{\partial w_k} $$
#
# $$ \frac{\partial \langle x_i,w\rangle}{\partial w_k} = x_{i,k}$$
#
# $$ \frac{\partial}{\partial w_k}(\langle x_i,w\rangle - y_i)^2 = 2(\langle x_i,w\rangle - y_i)\frac{\partial \langle x_i,w\rangle}{\partial w_k} = 2(\langle x_i,w\rangle - y_i) x_{i,k}$$
#
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{2}{N}\sum_i \left[ (\langle x_i,w\rangle - y_i) x_{i,k}\right] + \frac{2 w_k}{C} $$
#
# ***Для логистической регрессии:***
#
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{1}{N}\sum_i  \left[x_{i,k} \left(\sigma( \langle x_i,w\rangle)- y_i\right)\right] + \frac{2 w_k}{C}  = \frac{1}{N}\sum_i  \left[x_{i,k} \left(a(x_i)- y_i\right)\right] + \frac{2 w_k}{C} $$
# $$ a(x_i) =  \sigma( \langle\,x_i,w\rangle )$$
#
#
# ***Для линейной регрессии:***
#
# $$ \frac{\partial L(w)}{\partial w_k} = \frac{2}{N}\sum_i \left[x_{i,k}(\langle x_i,w\rangle - y_i)\right] + \frac{2 w_k}{C} = \frac{2}{N}\sum_i \left[x_{i,k}(a(x_i) - y_i)\right] + \frac{2 w_k}{C} $$
# $$ a(x_i) =  \langle\,x_i,w\rangle$$
#
#
#
# Видим, что вид градиентов почти один и тот же, за исключением множителя 2. Но по сути они различны, так как $a(x_i)$ разные. Отметим, что поведение градиента в обоих случаях одно и то же (смотри предыдущую задачу).

# %% [markdown]
# ### ***Задача 4.  Предсказываем вероятности***
#
# Когда говорят о логистической регрессии, произносят фразу, что она "предсказывает вероятности положительного класса". Давайте разберемся, что же за этим стоит. Посчитаем математическое ожидание функции потерь и проверим, что предсказание алгоритма, оптимизирующее это мат. ожидание, будет являться вероятностью положительного класса.
#
# И так, функция потерь на объекте $x_i$, который имеет метку $y_i \in \{0,1\}$  для предсказания $a(x_i)$ равна:
# $$L(y_i, b) =-[y_i == 1] \log a(x_i)  - [y_i == 0] \log(1 - a(x_i)) $$
#
# Где $[]$ означает индикатор $-$ он равен единице, если значение внутри него истинно, иначе он равен нулю. Тогда мат. ожидание при условии конкретного $x_i$  по определение мат. ожидания дискретной случайной величины:
# $$E(L | x_i) = -p(y_i = 1 |x_i ) \log a(x_i)  - p(y_i = 0 | x_i) \log( 1 - a(x_i))$$
# * Докажите, что значение $a(x_i)$, минимизирующее данное мат. ожидание, в точности равно $p(y_i = 1 |x_i)$, то есть равно вероятности положительного класса.
#
# Подсказка: возможно, придется воспользоваться, что  $p(y_i = 1 | x_i) + p(y_i = 0 | x_i) = 1$

# %% [markdown]
# ## ***Решение:***
#
# $$E(L | x_i) = -p(y_i = 1 |x_i ) \log a(x_i)  - p(y_i = 0 | x_i) \log( 1 - a(x_i))$$
#
#  $$\min\limits_{a(x_i)}E(L | x_i)$$
#
# $$ \frac{\partial E(L | x_i)}{\partial a(x_i)} = -\frac{p(y_i = 1 |x_i )}{a(x_i)} + \frac{p(y_i = 0 | x_i)}{1 - a(x_i)} = \frac{a(x_i)(p(y_i = 1 | x_i) + p(y_i = 0 | x_i)) - p(y_i = 1 | x_i)}{a(x_i)(1-(a(x_i))} = \frac{a(x_i) - p(y_i = 1|x_i)}{a(x_i)(1-(a(x_i))} $$
#
# $$\frac{a(x_i) - p(y_i = 1|x_i)}{a(x_i)(1-(a(x_i))}  = 0$$
#
# $$a(x_i) - p(y_i = 1|x_i)= 0$$
#
# $$a(x_i) = p(y_i = 1|x_i)$$
#
# $$ a(x_i) = \frac{1}{1 + \exp(-\langle\,x_i,w\rangle)}$$
# ч.т.д

# %%
x = np.linspace(0.1, 0.9, 100)
y = (x-0.3)/(x*(1-x))
plt.figure(figsize=(10, 8))
plt.plot(x, y, color = 'navy')

plt.xlabel(r'$a(x_i)$', fontsize = 16)
plt.ylabel(r'$\frac{\partial E(L | x_i)}{\partial a(x_i)}$', fontsize = 16)
plt.title('График зависимости '+ r'$\frac{\partial E(L | x_i)}{\partial a(x_i)}$' +
          ' от ' + r'$a(x_i)$' + ' если ' + r'$p(y_i = 1 |x_i ) = 0.3$', fontsize = 12)
plt.grid(linestyle ='--')
plt.show()

# %%
x = np.linspace(0.05, 0.6, 100)
y = -0.3*np.log(x)-0.7*np.log(1-x)
plt.figure(figsize=(10, 8))
plt.plot(x, y, color = 'navy')

plt.xlabel(r'$a(x_i)$', fontsize = 16)
plt.ylabel(r'$E(L | x_i)$', fontsize = 16)
plt.title('График зависимости '+ r'$E(L | x_i)$' + " от " +
          r'$a(x_i)$' + ' если ' + r'$p(y_i = 1 |x_i ) = 0.3$', fontsize = 12)
plt.grid(linestyle ='--')
plt.show()

# %% [markdown]
# #  Реализация логистической регрессии (6 баллов)

# %% [markdown]
# ## Зачем нужны батчи?

# %% [markdown]
# Как Вы могли заметить из теоретического введения, что в случае SGD, что в случа mini-batch GD,  на каждой итерации обновление весов  происходит только по небольшой части данных (1 пример в случае SGD, batch примеров в случае mini-batch). То есть для каждой итерации нам *** не нужна вся выборка***. Мы можем просто итерироваться по выборке, беря батч нужного размера (далее 1 объект тоже будем называть батчом).
#
# Легко заметить, что в этом случае нам не нужно загружать все данные в оперативную память, достаточно просто считать батч с диска, обновить веса, считать диска другой батч и так далее. В целях упрощения домашней работы, прямо с диска  мы считывать не будем, будем работать с обычными numpy array.

# %% [markdown]
# ## Немножко про генераторы в Python

# %% [markdown]
# Идея считывания данных кусками удачно ложится на так называемые ***генераторы*** из языка Python. В данной работе Вам предлагается не только разобраться с логистической регрессией, но  и познакомиться с таким важным элементом языка.  При желании Вы можете убрать весь код, связанный с генераторами, и реализовать логистическую регрессию и без них, ***штрафоваться это никак не будет***. Главное, чтобы сама модель была реализована правильно, и все пункты были выполнены.
#
# Подробнее можно почитать вот тут https://anandology.com/python-practice-book/iterators.html

# %% [markdown]
# К генератору стоит относиться просто как к функции, которая порождает не один объект, а целую последовательность объектов. Новое значение из последовательности генерируется с помощью ключевого слова ***yield***. Ниже Вы можете насладиться  генератором чисел Фибоначчи.

# %%
def fib(max_iter=4):
    a, b = 0, 1
    iter_num = 0
    while 1:
        yield a
        a, b = b, a + b
        iter_num += 1
        if iter_num == max_iter:
            break

# %% [markdown]
# Вот так можно сгенерировать последовательность Фибоначчи.
#
# Заметьте, что к генераторам можно применять некоторые стандартные функции из Python, например enumerate.

# %%
new_generator = fib(max_iter=10)
for j, fib_val in enumerate(new_generator):
    print ("Fib num: " + str(j) + " fib values: " + str(fib_val))
# Out:
# Fib num: 0 fib values: 0
# Fib num: 1 fib values: 1
# Fib num: 2 fib values: 1
# Fib num: 3 fib values: 2
# Fib num: 4 fib values: 3
# Fib num: 5 fib values: 5
# Fib num: 6 fib values: 8
# Fib num: 7 fib values: 13
# Fib num: 8 fib values: 21
# Fib num: 9 fib values: 34

# %% [markdown]
# Пересоздавая объект, можно сколько угодно раз генерировать заново последовательность.

# %%
for i in range(0, 3):
    new_generator = fib()
    for j, fib_val in enumerate(new_generator):
        print ("Fib num: " + str(j) + " fib values: " + str(fib_val))
# Out:
# Fib num: 0 fib values: 0
# Fib num: 1 fib values: 1
# Fib num: 2 fib values: 1
# Fib num: 3 fib values: 2
# Fib num: 0 fib values: 0
# Fib num: 1 fib values: 1
# Fib num: 2 fib values: 1
# Fib num: 3 fib values: 2
# Fib num: 0 fib values: 0
# Fib num: 1 fib values: 1
# Fib num: 2 fib values: 1
# Fib num: 3 fib values: 2

# %% [markdown]
# А вот так уже нельзя.

# %%
new_generator = fib()
for i in range(0, 3):
    for j, fib_val in enumerate(new_generator):
        print ("Fib num: " + str(j) + " fib values: " + str(fib_val))
# Out:
# Fib num: 0 fib values: 0
# Fib num: 1 fib values: 1
# Fib num: 2 fib values: 1
# Fib num: 3 fib values: 2

# %% [markdown]
# Концепция крайне удобная для обучения  моделей $-$ у Вас есть некий источник данных, который Вам выдает их кусками, и Вам совершенно все равно откуда он их берет. Под ним может скрывать как массив в оперативной памяти, как файл на жестком диске, так и SQL база данных. Вы сами данные никуда не сохраняете, оперативную память экономите.

# %% [markdown]
# Если Вам понравилась идея с генераторами, то Вы можете реализовать свой, используя прототип batch_generator. В нем Вам нужно выдавать батчи признаков и ответов для каждой новой итерации спуска. Если не понравилась идея, то можете реализовывать SGD или mini-batch GD без генераторов.

# %%
def batch_generator(X, y, shuffle=True, batch_size=1):
    """
    Гератор новых батчей для обучения
    X          - матрица объекты-признаки
    y_batch    - вектор ответов
    shuffle    - нужно ли случайно перемешивать выборку
    batch_size - размер батча ( 1 это SGD, > 1 mini-batch GD)
    Генерирует подвыборку для итерации спуска (X_batch, y_batch)
    """
    size = X.shape[0]
    index_array = np.arange(size)
    if shuffle:
        np.random.shuffle(index_array)
    for i in range(0, int(np.ceil(size/float(batch_size)))):
        batch_ids = index_array[i*batch_size: min(size, (i+1) * batch_size)]
        X_batch = X[batch_ids]
        y_batch = y[batch_ids]
        yield (X_batch, y_batch)

# Теперь можно сделать генератор по данным ()
# my_batch_generator = batch_generator(X, y, shuffle=False, batch_size=3)

# %%
# %%pycodestyle
# def sigmoid(X):
#     """
#     Вычисляем значение сигмоида.
#     X - матрица объекты-признаки
#     """
#     # Your code Here
#     return 1.0 / (1.0 + np.exp(-X))
#
#
# class MySGDClassifier_gen(BaseEstimator, ClassifierMixin):
#     """
#     Предполагается, что в выборке всегда 2 класса
#     """
#     def __init__(self, batch_generator, C=1, alpha=0.01, max_epoch=10):
#         """
#         batch_generator -- функция генератор, которой будем создавать батчи
#         C - коэф. регуляризации
#         alpha - скорость спуска
#         max_epoch - максимальное количество эпох
#         """
#         self.C = C
#         self.alpha = alpha
#         self.max_epoch = max_epoch
#         self.errors_log = {'iter': [], 'loss': []}
#
#     def calc_loss(self, X_batch, y_batch):
#         """
#         Считаем функцию потерь по батчу
#         X_batch - матрица объекты-признаки по батчу
#         y_batch - вектор ответов по батчу
#         """
#         sigma = sigmoid(X_batch.dot(self.weights))
#         one_loss = -(y_batch.dot(np.log(sigma))) / y_batch.size + \
#             (1 - y_batch).dot(np.log(1 - sigma)) / y_batch.size
#         two_loss = self.weights.dot(self.weights) / self.C
#         return one_loss + two_loss
#
#     def calc_loss_grad(self, X_batch, y_batch):
#         """
#         Считаем  градиент функции потерь по батчу
#         (то что Вы вывели в задании 1)
#         X_batch - матрица объекты-признаки по батчу
#         y_batch - вектор ответов по батчу
#         """
#         sigma_grad = sigmoid(X_batch.dot(self.weights))
#         one_grad = (X_batch.T).dot(sigma_grad - y_batch) / y_batch.size
#         two_grad = 2 * self.weights / self.C
#         return one_grad + two_grad
#
#     def update_weights(self, new_grad):
#         """
#         Обновляем вектор весов
#         new_grad - градиент по батчу
#         """
#         self.weights -= self.learning_rate * new_grad
#
#     def fit(self, X, y):
#         '''
#         Обучение модели
#         X - матрица объекты-признаки
#         y - вектор ответов
#         '''
#         X_ = np.c_[np.ones(X.shape[0]), X]
#         # Нужно инициализровать случайно веса
#         self.weights = np.random.rand(X_.shape[1])
#         self.costs = np.zeros(self.max_epoch)
#         for n in range(0, self.max_epoch):
#             self.learning_rate = self.alpha / (n + 1)
#             new_epoch_generator = batch_generator(X_,
#                                                   y,
#                                                   shuffle=True,
#                                                   batch_size=2)
#             for batch_num, new_batch in enumerate(new_epoch_generator):
#                 X_batch = new_batch[0]
#                 y_batch = new_batch[1]
#                 batch_loss = self.calc_loss(X_batch, y_batch)
#                 batch_grad = self.calc_loss_grad(X_batch, y_batch)
#                 self.update_weights(batch_grad)
#                 self.errors_log['iter'].append(batch_num)
#                 self.errors_log['loss'].append(batch_loss)
#             self.costs[n] = self.calc_loss(X_, y)
#         return self
#
#     def predict(self, X):
#         '''
#         Предсказание класса
#         X - матрица объекты-признаки
#         '''
#         # Желательно здесь использовать матричные операции
#         # между X и весами, например, numpy.dot
#         y_hat = self.predict_proba(X)[0] > 0.5
#         return y_hat
#
#     def predict_proba(self, X):
#         '''
#         Предсказание вероятности положительного класса
#         X - матрица объекты-признаки
#         '''
#         # Желательно здесь использовать матричные операции
#         # между X и весами, например, numpy.dot
#         X_ = np.c_[np.ones(X.shape[0]), X]
#         P = sigmoid(X_.dot(self.weights))
#         y_hat_proba = (P, 1 - P)
#         return y_hat_proba

# %%
# %%pycodestyle
# def sigmoid(X):
#     """
#     Вычисляем значение сигмоида.
#     X - матрица объекты-признаки
#     """
#     # Your code Here
#     return 1.0 / (1.0 + np.exp(-X))
#
#
# class MySGDClassifier(BaseEstimator, ClassifierMixin):
#     """
#     Предполагается, что в выборке всегда 2 класса
#     """
#     def __init__(self, C=1, alpha=0.01, max_epoch=10, batches=10):
#         """
#         batch_generator -- функция генератор, которой будем создавать батчи
#         C - коэф. регуляризации
#         alpha - скорость спуска
#         max_epoch - максимальное количество эпох
#         """
#         self.C = C
#         self.alpha = alpha
#         self.max_epoch = max_epoch
#         self.batches = batches
#         self.errors_log = {'iter': [], 'loss': []}
#
#     def calc_loss(self, X_batch, y_batch):
#         """
#         Считаем функцию потерь по батчу
#         X_batch - матрица объекты-признаки по батчу
#         y_batch - вектор ответов по батчу
#         """
#         sigma = sigmoid(X_batch.dot(self.weights))
#         one_loss = -(y_batch.dot(np.log(sigma))) / y_batch.size + \
#             (1 - y_batch).dot(np.log(1 - sigma)) / y_batch.size
#         two_loss = self.weights.dot(self.weights) / self.C
#         return one_loss + two_loss
#
#     def calc_loss_grad(self, X_batch, y_batch):
#         """
#         Считаем  градиент функции потерь по батчу
#         (то что Вы вывели в задании 1)
#         X_batch - матрица объекты-признаки по батчу
#         y_batch - вектор ответов по батчу
#         """
#         sigma_grad = sigmoid(X_batch.dot(self.weights))
#         one_grad = (X_batch.T).dot(sigma_grad - y_batch) / y_batch.size
#         two_grad = 2 * self.weights / self.C
#         return one_grad + two_grad
#
#     def update_weights(self, new_grad):
#         """
#         Обновляем вектор весов
#         new_grad - градиент по батчу
#         """
#         self.weights -= self.learning_rate * new_grad
#
#     def fit(self, X, y):
#         '''
#         Обучение модели
#         X - матрица объекты-признаки
#         y - вектор ответов
#         '''
#         X_ = np.c_[np.ones(X.shape[0]), X]
#         # Нужно инициализровать случайно веса
#         self.weights = np.random.rand(X_.shape[1])
#         self.costs = np.zeros(self.max_epoch)
#         for n in range(0, self.max_epoch):
#             self.learning_rate = self.alpha / (n + 1)
#             inds = np.arange(X.shape[0])
#             np.random.shuffle(inds)
#             batches = np.array_split(inds, self.batches)
#             for batch_num, new_batch in enumerate(batches):
#                 X_batch = X_[new_batch]
#                 y_batch = y[new_batch]
#                 batch_loss = self.calc_loss(X_batch, y_batch)
#                 batch_grad = self.calc_loss_grad(X_batch, y_batch)
#                 self.update_weights(batch_grad)
#                 self.errors_log['iter'].append(batch_num)
#                 self.errors_log['loss'].append(batch_loss)
#             self.costs[n] = self.calc_loss(X_, y)
#         return self
#
#     def predict(self, X):
#         '''
#         Предсказание класса
#         X - матрица объекты-признаки
#         '''
#         # Желательно здесь использовать матричные операции
#         # между X и весами, например, numpy.dot
#         y_hat = self.predict_proba(X)[0] > 0.5
#         return y_hat
#
#     def predict_proba(self, X):
#         '''
#         Предсказание вероятности положительного класса
#         X - матрица объекты-признаки
#         '''
#         # Желательно здесь использовать матричные операции
#         # между X и весами, например, numpy.dot
#         X_ = np.c_[np.ones(X.shape[0]), X]
#         P = sigmoid(X_.dot(self.weights))
#         y_hat_proba = (P, 1 - P)
#         return y_hat_proba

# %% [markdown]
# Запустите ваш алгоритм на синтетических данных.
#
# Выведите полученные веса и нарисуйте разделяющую границу между классами (используйте только первых два веса для первых двух признаков X[:,0], X[:,1] для отображения в 2d пространство ).

# %%
def plot_decision_boundary(clf):
    # Your code Here
    plt.figure(figsize=(20, 10))
    plt.scatter(X[:, 0], X[:, 1], c=y)
    W = clf.weights
    text = r''
    for (i, w) in enumerate(W):
        text = text + '\n' + r'$\omega_{} = {}$'.format(i, w)
    x = np.linspace(X[:, 0].min(), X[:, 0].max(), 100)
    plt.ylim((-6, 4))
    plt.plot(x, -(W[0] + W[1] * x) / W[2], 'orange', linewidth=2.0)
    plt.text(-5.5, 1, text, fontsize=15)
    plt.title("MySGDClassifier", fontsize=20)
    plt.show()

# %%
np.random.seed(0)
C1 = np.array([[0., -0.8], [1.5, 0.8]])
C2 = np.array([[1., -0.7], [2., 0.7]])
gauss1 = np.dot(np.random.randn(200, 2) + np.array([5, 3]), C1)
gauss2 = np.dot(np.random.randn(200, 2) + np.array([1.5, 0]), C2)

X = np.vstack([gauss1, gauss2])
y = np.r_[np.ones(200), np.zeros(200)]
# X = StandardScaler().fit_transform(X)
# y = StandardScaler().fit_transform(y.reshape(-1,1)).ravel()
# plot_decision_boundary(your_model)
model1 = MySGDClassifier(C=1e5, alpha=1, max_epoch=100)
model1.fit(X, y)
plot_decision_boundary(model1)

# %% [markdown]
# Далее будем анализировать Ваш алгоритм.
# Для этих заданий используйте датасет ниже.

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=100000, n_features=10, 
                           n_informative=4, n_redundant=0, 
                           random_state=123, class_sep=1.0,
                           n_clusters_per_class=1)

# %% [markdown]
# Покажите сходимость вашего метода на этом датасете: изобразите график  функции потерь, усредненной по $N$ шагам градиентого спуска, для разных `alpha` (размеров шага). Разные `alpha` расположите на одном графике.
#
# $N$ можно брать 10, 50, 100 и т.д.

# %%
# Your Code Here
alphas = [0.2, 0.4, 0.8, 1, 2, 4]
fig, ax = plt.subplots(figsize=(20, 10))
for alpha in alphas:
    model = MySGDClassifier(C=1e4, alpha=alpha, max_epoch=100, batches=50)
    model.fit(X, y)
    ax.plot(model.costs, label=r'$\alpha=%.3f$' % alpha)
    ax.legend()
    ax.set_ylabel('logloss')
    ax.set_xlabel('epoch')
plt.show()

# %% [markdown]
# Что Вы можете сказать про сходимость метода при различных `alpha`? Какое значение стоит выбирать для лучшей сходимости?

# %% [markdown]
# ## ***Ответ:***
#
# Из графика следует, что чем меньше $\alpha$,  тем медленнее происходит сходимость к минимуму функции потерь, так как шаг градиентного спуска меньше, чем меньше $\alpha$. Если мы берем большие $\alpha$, то сходимость происходит быстрее, но мы можем пропустить, "проскочить" точку минимума.

# %% [markdown]
# Изобразите график среднего значения весов модели в зависимости от коеф. регуляризации С из `np.logspace(3, -3, 10)`

# %%
# Your Code Here
C = np.logspace(3, -3, 10)
N = X.shape[1] + 1
M = C.size
W = np.zeros((M, N))

for (i, c) in enumerate(C):
    model = MySGDClassifier(C=c, alpha=0.3, max_epoch=100)
    model.fit(X, y)
    W[i, :] = model.weights
# Out:
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in log
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in log
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:37: RuntimeWarning: overflow encountered in double_scalars
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:49: RuntimeWarning: overflow encountered in true_divide

# %%
fig, ax = plt.subplots(figsize=(20, 10))
for i in range(N):
    ax.semilogx(C, W[:, i], label=r'$w_{%d}$' % i)

ax.legend(bbox_to_anchor=(1.15, 1), fontsize=20)
ax.set_ylabel('weight')
ax.set_xlabel('C')
ax.set_title('My regularizaton')
plt.show()

# %% [markdown]
# Довольны ли Вы, насколько сильно уменьшились Ваши веса? Если нет, то как можно было бы уменьшать их еще сильнее?

# %% [markdown]
# ## ***Ответ:***
#
# Видно, что при малом $C$ веса стремятся к нулю. Это связано с тем, что $C^{-1}$ становится большим и регуляризующее слагаемое доминирует в функции потерь. Тогда для $L_2$-регуляризации функция потерь приближенно становится параболической с минимумом в нуле.
#
# Результат меня порадовал. Можно было бы использовать другую метрику. Например $L_1$-регуляризацию, которая бы занулила некоторые незначимые весы.

# %% [markdown]
# # Боевое применение (2  балла)

# %% [markdown]
# ## О hearthstone

# %% [markdown]
# [Hearthstone](http://eu.battle.net/hearthstone/ru/) - карточная онлайн игра по мотивам вселенной Warcraft.
#
# Каждый игрок играет за персонажа определенного класса и собирает колоду карт которую может разыгрывать во время игры. Для дальнейших деталей обратитесь к [wiki](https://ru.wikipedia.org/wiki/Hearthstone), посмотрите youtube или поиграйте сами (но не долго =) ).
#
# Теми или иными способами игрок может отнимать жизни у своего оппонента, таким образом цель раунда - побить другого игрока.

# %% [markdown]
# <center><img src='http://ps3hits.ru/wp-content/uploads/2015/08/hearthstone-game-sshot-1.jpg'></center>

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# В рамках конференции [AAIA 17](https://fedcsis.org/2017/aaia) было запущено [соревнование](https://knowledgepit.fedcsis.org/contest/view.php?id=120) по предсказанию исхода раунда в heartstone.
#
# Используя признаки, которые описывают текущее состояние раунда необходимо предсказать **вероятность** победы игрока в этом раунде.
#
# Качество модели измеряется с помощью **ROC-AUC**

# %% [markdown]
# ## Данные
#
# Обучающую выборку и тестовую выборку с ответами можно скачать [отсюда](https://cloud.mail.ru/public/BEon/4Rrdqqvng)
#
# Данные содержат набор информации о раунде в некоторый момент времени: жизни игрока и оппонента, номер хода, карты на столе, карты в руке игрока, количество карт в руке оппонента и тп.<br/>
# По игроку №1 (далее просто **игрок**) помимо всего прочего известен набор карт "в руке".</br>
# По игроку №2 (далее просто **оппонент**) эта информация отсутствует.</br>
#
#
# В данных для обучению содержится 2 млн. игр, разбитых на 4 файла. Названия признаков говорят сами за себя.
# Целевой признак - `decision` (1 - победил игрок, 0 - победил оппонент).

# %%
# Загрузка данных для обучения
filepath = 'data/trainingData_tabular_chunk1.csv'
df_data = pd.read_csv(filepath, sep=',')

# %%
df_data.head()
# Out:
#    gamestate_id  decision  turn  opponent.armor  opponent.attack  \
# 0       4687346         1    14               0                0
# 1       3270826         1     7               0                0
# 2       3189487         1     5               3                0
# 3       4098946         1     8               0                0
# 4       2661127         0    13               0                0
#
#    opponent.hero_card_id  opponent.hp  opponent.special_skill_used  \
# 0                    798            5                            0
# 1                    754           22                            0
# 2                    612           29                            0
# 3                    390           26                            0
# 4                     25           30                            0
#
#    opponent.weapon_durability  opponent.crystals_all       ...        \
# 0                           0                     10       ...
# ...

# %%
# для удобства
df_data.columns = df_data.columns.str.replace('.', '_')
df_data = df_data.set_index('gamestate_id')

# %%
df_data.head().T
# Out:
# gamestate_id                   4687346  3270826  3189487  4098946  2661127
# decision                             1        1        1        1        0
# turn                                14        7        5        8       13
# opponent_armor                       0        0        3        0        0
# opponent_attack                      0        0        0        0        0
# opponent_hero_card_id              798      754      612      390       25
# opponent_hp                          5       22       29       26       30
# opponent_special_skill_used          0        0        0        0        0
# opponent_weapon_durability           0        0        0        0        0
# opponent_crystals_all               10        6        4        7       10
# opponent_crystals_current           10        6        1        7        1
# opponent_deck_count                 11       19       22       17       12
# ...

# %%
# Распределение классов
df_data.decision.mean()
# Примерно поровну
# Out:
# 0.504702

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# * Получите матрицу объект признак `X` и вектор целевого признака `y`
# * Преобразуйте категориальные переменные с помощью one-hot кодирования, добавьте к датасету и удалите прежние столбцы. (Вы точно понимаете, зачем это нужно сделать? Если нет, спросите обязательно преподавателя!)
# * Стандартизируйте признаки с помощью `StandartScaller` из sklearn (Вы точно понимаете, зачем это нужно сделать? Если нет, спросите обязательно преподавателя!)
# * Обучите модель, подбирая параметры на отложенном контроле

# %% [markdown]
# ## Применение модели
# * Подготовьте тестовые данные  к подаче на вход в алгоритму (нужно сделать такие же преобразования, как при обучении)
# * Примените модель оцените качество на тесте с помощью меры ROC-AUC (имплментацию взять из sklern.metrics)

# %%
# Загрузка данных для тестирования
filepath_test = 'data/trainingData_tabular_chunk2.csv'
df_data_test = pd.read_csv(filepath_test, sep=',')

# %%
# Youd Code Here


def preprocessing(df):
    one_hot_opponent = pd.get_dummies(df['opponent_hero_card_id'],
                                      prefix='opponent',
                                      drop_first=True)
    one_hot_player = pd.get_dummies(df['player_hero_card_id'],
                                    prefix='player',
                                    drop_first=True)
    one_hot_data = df.join(one_hot_opponent)
    one_hot_data = one_hot_data.join(one_hot_player)
    return one_hot_data.drop(['opponent_hero_card_id',
                              'player_hero_card_id'], axis=1)


one_hot_data = preprocessing(df_data)
one_hot_data.head().T
# Out:
# gamestate_id                   4687346  3270826  3189487  4098946  2661127
# decision                             1        1        1        1        0
# turn                                14        7        5        8       13
# opponent_armor                       0        0        3        0        0
# opponent_attack                      0        0        0        0        0
# opponent_hp                          5       22       29       26       30
# opponent_special_skill_used          0        0        0        0        0
# opponent_weapon_durability           0        0        0        0        0
# opponent_crystals_all               10        6        4        7       10
# opponent_crystals_current           10        6        1        7        1
# opponent_deck_count                 11       19       22       17       12
# opponent_fatigue_damage              0        0        0        0        0
# ...

# %%
y = one_hot_data['decision'].values
X = np.float64(one_hot_data[one_hot_data.columns[1:]].values)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, train_test_split
from tqdm import tqdm
from itertools import product

# %%
model = Pipeline([
    ('sclr', StandardScaler()),
    ('clf', MySGDClassifier()),
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                    random_state=42)

C = [100, 500]
alphas = [2, 2.5, 3, 3.5, 4]
batches = [1, 5, 10, 50]
max_epoch = 100
scores = []
params = []
parameters = product(C, alphas, batches)
parameters_list = list(parameters)

# %%
# %%time
for param in tqdm(parameters_list, total = len(parameters_list)):
    model.set_params(clf__C=param[0],
                     clf__alpha=param[1],
                     clf__max_epoch=max_epoch,
                     clf__batches=param[2])
    model.fit(X_train, y_train)
    y_pred = model.predict_proba(X_test)[0]
    scores.append(roc_auc_score(y_test, y_pred))
    params.append((param[0], param[1], param[2]))
# Out:
# ...
# 100%|██████████| 40/40 [15:15<00:00, 20.38s/it]
# CPU times: user 51min 58s, sys: 1h 2min 10s, total: 1h 54min 9s
# Wall time: 15min 15s

# %%
print('best score: %f' % np.max(scores))
best_params = params[np.argmax(scores)]
# Out:
# best score: 0.785278

# %%
model.set_params(clf__C=best_params[0],
                 clf__alpha=best_params[1],
                 clf__max_epoch=max_epoch,
                 clf__batches=best_params[2])
model.fit(X, y)
# Out:
# /home/evgenii/.local/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in log
# Pipeline(memory=None,
#      steps=[('sclr', StandardScaler(copy=True, with_mean=True, with_std=True)), ('clf', MySGDClassifier(C=500, alpha=2, batches=50, max_epoch=100))])

# %%
df_list = []
for i in range(5, 8):
    filepath = 'data/testData_tabular_chunk%d.csv' % i
    df_list.append(pd.read_csv(filepath, sep=','))
df_test = pd.concat(df_list)
df_test.columns = df_test.columns.str.replace('.', '_')
df_test = df_test.set_index('gamestate_id')
df_test = df_test.drop(['decision'], axis=1)

y_test = []
with open('data/deprecated_testLabels.txt', 'r') as data:
    for val in data.read().split():
        y_test.append(int(val))

y_test = np.array(y_test)
X_test = np.float64(preprocessing(df_test).values)

y_pred = model.predict_proba(X_test)[0]

print('ROC-AUC: %f' % roc_auc_score(y_test, y_pred))

fpr, tpr, _ = roc_curve(y_test, y_pred)
plt.figure(figsize=(8, 8))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC')
plt.plot(fpr, tpr)
plt.show()
# Out:
# ROC-AUC: 0.796268

# %% [markdown]
# # Контрольные вопросы
# Постарайтесь максимально развернуто и честно ответить на вопросы. Они охватывают тему линейных моделей и скорее нужны преподавателям, чтобы понимать, что именно Вы усвоили плохо. Надеюсь, они подскажут, что именно в теме Вы не понимаете или наоборот порадают, что Вы все знаете ^_^

# %% [markdown]
# ---
# ### ***Вопрос №1:***
# * Опишите основные, на Ваш взгляд,  отличия логистической регрессии от линейной регрессии. Почему, на ваш взгляд, задачу классификации решают логистической, а не линейной регрессией?

# %% [markdown]
# ### ***Ответ:***
#
# * Выражение $\langle w , x \rangle = 0$ является уравнением некоторой плоскости в пространстве признаков. При этом для точек по одну сторону от этой плоскости скалярное произведение $\langle w , x \rangle$ будет положительным, а с другой — отрицательным. Таким образом, линейный классификатор проводит гиперплоскость в пространстве признаков и относит объекты по разные стороны от нее к разным классам. Согласно геометрическому смыслу скалярного произведения, расстояние от конкретного объекта, который имеет признаковое описание x, до гиперплоскости $\langle w , x \rangle = 0$ равно $\frac { | \langle w , x \rangle | } { \| w \| }$. С этим связано понятие отступа: $M _ { i } = y _ { i } \left\langle w , x _ { i } \right\rangle$. Отступ является величиной, определяющей корректность ответа. Если оступ больше нуля $M_i > 0$, то классификатор дает верный ответ для $i$-го объекта, в ином случае — ошибается. Причем чем дальше отступ от нуля, тем больше уверенность как в правильном ответе, так и в том, что алгоритм ошибается. Если отступ для некоторого объекта отрицательный и большой по модулю, это значит, что алгоритм неправильно описывает данные: либо этот объект является выбросом, либо алгоритм не пригоден для решения данной задачи.
# * В модели линейной регрессии нет способа оценить, насколько мы точно определили класс, а в модели логистической регрессии есть (требуется, чтобы алгоритм возвращал вероятность класса $y=+1: h(x,w) = p(y=+1|x,w) = \sigma(g(x))$).
# * Отметим то, что в линейной регрессии зависимая переменная является непрерывным. Он может иметь любое из бесконечного числа возможных значений. В логистической регрессии зависимая переменная имеет только ограниченное число возможных значений.

# %% [markdown]
# ### ***Вопрос №2:***
# * Как Вы думаете, для каких типов задач (объем данных, число признаков, типы признаков) стоит отдавать предпочтение линейным моделям?

# %% [markdown]
# ### ***Ответ:***
#
# Линейные модели могут хорошо работать на больших выборках, даже если данные разрежены. Если признаков очень много некоторые нелинейные модели работают плохо и долго. При работе с линейными моделями необходимо бороться с мультиколлинеарностью. Линейные модели работают лучше с вещественными признаками.

# %% [markdown]
# ### ***Вопрос №3:***
# * Пусть на обучении мы имеем выборку размера $N$, число признаков $D$. Чему равна алгоритмическая сложность одного шага градиентного спуска? Cтохастического градиентного спуска?  Сложность предсказания на одном объекте?

# %% [markdown]
# ### ***Ответ:***
#
# * Имеем:
# > выборка размера  𝑁
# > число признаков  𝐷
#
# $ \frac{\partial L(w)}{\partial w_k} = \frac{1}{N}\sum_i  \left[x_{i,k} \left(\sigma( \langle x_i,w\rangle)- y_i\right)\right] + \frac{2 w_k}{C}$
#
# $ w_k := w_k - \alpha\frac{\partial L(w)}{\partial w_k},\  \alpha$ - скорость спуска
#
# Далее:
#
# * Для шага градиентного спуска  каждого $w_k$ где $k = 1,...,D$ вычисляется сумма из N слагаемых, в каждом слагаемом нужно вычислить скалярное произведение  $\langle x_i,w\rangle$, где $w$ вектор длины D.
# В итоге получаем, алгоритмическая сложность одного шага градиентного спуска:
# $$O(D * N * D) = O (N * D^2)$$
# * Для шага стохастического градиентного спуска нужен только один объект обучающей выборки, поэтому получаем, алгоритмическая сложность одного шага стохастического градиентного спуска:
# $$O(D * 1 * D) = O (D^2)$$
# * Для предсказания на одном объекте нужно только вычислить  скалярное произведение двух векторов длины D. Тогда получаем, что алгоритмическая сложность:
# $$O(D)$$

# %% [markdown]
# ### ***Вопрос №4:***
#
# * В чем преимущества стохастического градиентного спуска (в том числе мини-батч) над обычным градиентным спуском? В чем его недостатки? Рассмотрите несколько аспектов $-$ скорость сходимости, необходимость загрузки всех данных в оперативную память, сложность вычисления одного шага.

# %% [markdown]
# ### ***Ответ:***
#
# - [x] При стохастичсеком градиентном спуске (в том числе мини-батч) не требуется загружать все данные в оперативную память.
# - [x] Для больших массивов данных стохастический градиентный спуск может дать значительное преимущество в скорости по сравнению со стандартным градиентным спуском. Не всегда нужно проходить по всей тренировочной выборке, можно получить уже приемлемые результаты на нескольких шагах стохастического градиентного спуска
# - [x] Сложность вычисления одного шага в случае стохастического градиентного спуска намного меньше, чем в модели стандартного градиентного спуска

# %% [markdown]
# ### ***Вопрос №5:***
#
# * Как Вы думаете, при обучении линейной модели с помощью SGD, ошибку на новом объекте стоит считать до итерации спуска на этом объекте или после? Почему Вы так думаете? Возможно, Вам будет интересно ознакомиться с http://hunch.net/~jl/projects/prediction_bounds/thesis/mathml/thesisse44.xml

# %% [markdown]
# ### ***Ответ:***
#
# * Я думаю, что при обучении линейной модели с помощью SGD, ошибку на новом объекте стоит считать до итерации спуска на этом объекте, так как тогда модель еще не видела этот объект. На следующей итерации этот объект модель уже учитывает, спуск произошел, и ошибка должна быть меньше.

# %% [markdown]
# ### ***Вопрос №6:***
#
# * Как Вы думаете, во времена такого бума нейронных сетей, остаются ли популярными линейные модели, или это уже пережиток прошлого? Почему Вы так думаете?

# %% [markdown]
# ### ***Ответ:***
#
# * Линейные модели - очень простые, их легко быстро построить, иногда в некоторых бизнес-задачах не нужны какие-то сложные алгоритмы, достаточно простой линейной модели, кроме того они являются строительным блоком для создания более сложных аналитических моделей, поэтому их нужно знать. В свою же очередь, хорошую нейронную сеть иногда не так легко построить, нужно рассматривать различные архитектуры,а это целое искусство.

# %% [markdown]
# ### ***Вопрос №7:***
#
# * Какие аспекты обучения линейных моделей Вам показались непонятными? Какое место стоит дополнительно объяснить?

# %% [markdown]
# ### ***Ответ:***
# * Все было понятно.
# ---

# %% [markdown]
# Здесь Вы можете оставить отзыв о этой домашней работе или о всем курсе.

# %% [markdown]
# ***Отличная лекция. Домашняя работа очень интересная и объёмная.***
